# %% [markdown]
# <a href="https://colab.research.google.com/github/uddin007/DeepSeek-RAG-application/blob/main/deepseek_r1_distill_llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.44.2 mlflow langchain cloudpickle langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.3/28.3 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 109.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 81.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.0/413.0 kB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 98.5 MB/s eta 0:00:00
# ...

# %%
# model_id = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

# %%
# %cd /content/drive/MyDrive/DeepSeek
# Out:
# /content/drive/MyDrive/DeepSeek

# %%
# import os

# LOCAL_DISK_HF = "/content/drive/MyDrive/DeepSeek"
# os.makedirs(LOCAL_DISK_HF, exist_ok=True)
# os.environ["HF_HOME"] = LOCAL_DISK_HF
# os.environ["HF_DATASETS_CACHE"] = LOCAL_DISK_HF
# os.environ["TRANSFORMERS_CACHE"] = LOCAL_DISK_HF

# %%
# from huggingface_hub import snapshot_download
# snapshot_download(model_id)

# %%
# import transformers
# import torch
# import cloudpickle
# import mlflow
# import mlflow.transformers
# from mlflow.models import infer_signature

# uc_model_name = "deepseek_r1_distilled_llama8b_v1"
# task = "llm/v1/chat"

# # Check if GPU is available
# device = "cuda" if torch.cuda.is_available() else "cpu"

# # Load model and move to GPU
# model = transformers.AutoModelForCausalLM.from_pretrained(
#     model_id,
#     device_map="auto",  # This will automatically handle model placement
#     torch_dtype=torch.float16  # Use half precision to save memory
# )

# # Load tokenizer
# tokenizer = transformers.AutoTokenizer.from_pretrained(model_id)

# # Create transformers model dictionary
# transformers_model = {"model": model, "tokenizer": tokenizer}

# # Log model with MLflow
# with mlflow.start_run():
#     model_info = mlflow.transformers.log_model(
#         transformers_model=transformers_model,
#         artifact_path="model",
#         task=task,
#         registered_model_name=f"main.msh.{uc_model_name}",
#         metadata={
#             "task": task,
#             "pretrained_model_name": "meta-llama/Llama-3.3-8B-Instruct",
#             "databricks_model_family": "LlamaForCausalLM",
#             "databricks_model_size_parameters": "8b",
#             "device": device
#         },
#     )
# Out:
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# ...
# model-00001-of-000002.safetensors:   0%|          | 0.00/8.67G [00:00<?, ?B/s]
# model-00002-of-000002.safetensors:   0%|          | 0.00/7.39G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.06k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/19.0k [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# ...

# %%
model_uri = "runs:/f7f8c8f4cf4e4b18801df96a3e027636/model"

# %%
# Load the model from MLflow
import mlflow.transformers

loaded_model = mlflow.transformers.load_model(model_uri=model_uri)
# Out:
# 2025/02/10 04:05:19 INFO mlflow.transformers: 'runs:/f7f8c8f4cf4e4b18801df96a3e027636/model' resolved as 'file:///content/drive/MyDrive/DeepSeek/mlruns/0/f7f8c8f4cf4e4b18801df96a3e027636/artifacts/model'
# 2025/02/10 04:05:30 WARNING mlflow.transformers.model_io: Could not specify device parameter for this pipeline type.Falling back to loading the model with the default device.
# Loading checkpoint shards:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
print(loaded_model)

# %%
from transformers import pipeline
import torch
from langchain import PromptTemplate, LLMChain
from langchain.llms import HuggingFacePipeline
import markdown

def generate_response(prompt, model, tokenizer):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(**inputs, max_new_tokens=5000)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Remove everything before and including '</think>'
    if "</think>" in response:
        response = response.split("</think>")[-1].strip()

    return response

# Load Model & Tokenizer
model = loaded_model.model
tokenizer = loaded_model.tokenizer

# Create the text-generation pipeline
text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device=0 if torch.cuda.is_available() else -1,
    max_new_tokens=5000,
    temperature=0.9,
    do_sample=True
)

# Create a HuggingFacePipeline
llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# Define a simple prompt template
template = """Question: {question}

Answer:"""
prompt = PromptTemplate(template=template, input_variables=["question"])

# Create the LLMChain
llm_chain = LLMChain(prompt=prompt, llm=llm)

# Run the chain and clean output
question = '''
          If the sum of three consecutive odd numbers is 45, what are the numbers?
          '''
response = llm_chain.run(question).strip()

# Remove echoes of the question if present in response
if question in response:
    response = response.replace(question, "").strip()

# Remove everything before and including '</think>'
if "</think>" in response:
    response = response.split("</think>")[-1].strip()

print(response)
# Out:
# The three consecutive odd numbers whose sum is 45 are 13, 15, and 17.
#
# **Step-by-Step Explanation:**
#
# 1. **Define Variables:** Let the three consecutive odd numbers be \( x \), \( x + 2 \), and \( x + 4 \).
#
# 2. **Set Up the Equation:** The sum of these numbers is 45.
#    \[
#    x + (x + 2) + (x + 4) = 45
#    \]
#
# 3. **Combine Like Terms:**
#    \[
#    3x + 6 = 45
#    \]
#
# 4. **Solve for \( x \):**
#    \[
#    3x = 45 - 6
#    \]
#    \[
#    3x = 39
#    \]
#    \[
#    x = \frac{39}{3} = 13
#    \]
#
# 5. **Find the Numbers:**
#    \[
#    \text{First number} = 13
#    \]
#    \[
#    \text{Second number} = 13 + 2 = 15
#    \]
#    \[
#    \text{Third number} = 15 + 2 = 17
#    \]
#
# 6. **Verify the Sum:**
#    \[
#    13 + 15 + 17 = 45
#    \]
#
# **Answer:** The three consecutive odd numbers are 13, 15, and 17.

# %%
import mlflow.transformers
import torch

# Load the model using mlflow.transformers.load_model
loaded_model = mlflow.transformers.load_model("/content/drive/MyDrive/DeepSeek/mlruns/0/f7f8c8f4cf4e4b18801df96a3e027636/artifacts/model")

# Access the underlying PyTorch model
model = loaded_model.model

# Script and save the model if needed
scripted_model = torch.jit.script(model)
scripted_model.save("deepseek8b.pt")
# Out:
# 2025/02/10 05:41:41 WARNING mlflow.transformers.model_io: Could not specify device parameter for this pipeline type.Falling back to loading the model with the default device.
# Loading checkpoint shards:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
# !torch-model-archiver --model-name deepseek8b --version 1.0 --serialized-file deepseek8b.pt --handler text_handler.py --export-path model_store
# !torchserve --start --ncs --model-store model_store --models deepseek8b.mar
# Out:
# /bin/bash: line 1: torch-model-archiver: command not found
# /bin/bash: line 1: torchserve: command not found

# %%
# !pip install vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.3/264.3 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 81.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...

# %%
# !python -m vllm.entrypoints.openai.api_server --model /content/drive/MyDrive/DeepSeek/mlruns/0/f7f8c8f4cf4e4b18801df96a3e027636/artifacts/model
# Out:
# 2025-02-10 05:45:48.223715: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-10 05:45:48.241501: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739166348.263532   30544 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739166348.270258   30544 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
